# %% [markdown]
# ### Determine the smallest positive float of your Python installation by using a whileloop

# %%
flow of control:
    while
    if
    for

# %%
x =1.0

# %%
type(x)
# Out:
# float

# %%
x = 1.0


while x>0:
    x /= 2.
    print(x)
    
 # the last number before zero is your answer
# Out:
# 0.5
# 0.25
# 0.125
# 0.0625
# 0.03125
# 0.015625
# 0.0078125
# 0.00390625
# 0.001953125
# 0.0009765625
# 0.00048828125
# 0.000244140625
# 0.0001220703125
# 6.103515625e-05
# 3.0517578125e-05
# 1.52587890625e-05
# 7.62939453125e-06
# 3.814697265625e-06
# 1.9073486328125e-06
# 9.5367431640625e-07
# 4.76837158203125e-07
# 2.384185791015625e-07
# 1.1920928955078125e-07
# 5.960464477539063e-08
# 2.9802322387695312e-08
# 1.4901161193847656e-08
# 7.450580596923828e-09
# 3.725290298461914e-09
# 1.862645149230957e-09
# 9.313225746154785e-10
# 4.656612873077393e-10
# 2.3283064365386963e-10
# 1.1641532182693481e-10
# 5.820766091346741e-11
# 2.9103830456733704e-11
# 1.4551915228366852e-11
# 7.275957614183426e-12
# 3.637978807091713e-12
# 1.8189894035458565e-12
# 9.094947017729282e-13
# 4.547473508864641e-13
# 2.2737367544323206e-13
# 1.1368683772161603e-13
# 5.684341886080802e-14
# 2.842170943040401e-14
# 1.4210854715202004e-14
# 7.105427357601002e-15
# 3.552713678800501e-15
# ...

# %% [markdown]
# ### Determine the numerical accuracy of the installation. Add smaller and smaller numbers to 1. and compare the result with 1

# %%
x = 1.

while 1.+x>1.: #once the accuracy fails the number will be less than 1
    x /= 2.
    print(x)
# Out:
# 0.5
# 0.25
# 0.125
# 0.0625
# 0.03125
# 0.015625
# 0.0078125
# 0.00390625
# 0.001953125
# 0.0009765625
# 0.00048828125
# 0.000244140625
# 0.0001220703125
# 6.103515625e-05
# 3.0517578125e-05
# 1.52587890625e-05
# 7.62939453125e-06
# 3.814697265625e-06
# 1.9073486328125e-06
# 9.5367431640625e-07
# 4.76837158203125e-07
# 2.384185791015625e-07
# 1.1920928955078125e-07
# 5.960464477539063e-08
# 2.9802322387695312e-08
# 1.4901161193847656e-08
# 7.450580596923828e-09
# 3.725290298461914e-09
# 1.862645149230957e-09
# 9.313225746154785e-10
# 4.656612873077393e-10
# 2.3283064365386963e-10
# 1.1641532182693481e-10
# 5.820766091346741e-11
# 2.9103830456733704e-11
# 1.4551915228366852e-11
# 7.275957614183426e-12
# 3.637978807091713e-12
# 1.8189894035458565e-12
# 9.094947017729282e-13
# 4.547473508864641e-13
# 2.2737367544323206e-13
# 1.1368683772161603e-13
# 5.684341886080802e-14
# 2.842170943040401e-14
# 1.4210854715202004e-14
# 7.105427357601002e-15
# 3.552713678800501e-15
# ...

# %%
"~%10.3e~" % 1.2345
# Out:
# '~ 1.234e+00~'

# %%
 "~%09d~" % 123
# Out:
# '~000000123~'

# %%
 "~%8.4f~" % 123
# Out:
# '~123.0000~'

# %%
f = open("test.dat")

# %%
f.readline()
# Out:
# '0.026294\t0.683060\n'

# %%
f.seek(0)
# Out:
# 0

# %%
for line in f:
    x = f.readline()
    y = x.split()
    print(float(y[0])+float(y[1]))
# Out:
# 1.3666019999999999
# 1.457261
# 1.5461239999999998
# 1.187117
# 1.580646
# 0.88348
# 0.869202
# 0.517178
# 0.323256
# 1.358142
# 1.492379
# 1.159371
# 1.086336
# 0.124333
# 0.9915499999999999
# 0.673523
# 0.9572660000000001
# 0.9719450000000001
# 1.737012
# 0.410687
# 1.013174
# 1.592068
# 1.106082
# 1.240106
# 0.29863
# 0.9315880000000001
# 0.441905
# 0.514395
# 1.186445
# 0.838526
# 0.059967
# 1.4403000000000001
# 0.334739
# 0.9808209999999999
# 1.0666660000000001
# 1.174444
# 0.550475
# 1.4634019999999999
# 0.156962
# 1.402221
# 0.787945
# 0.371255
# 0.8796029999999999
# 0.506469
# 1.001866
# 0.847616
# 1.452588
# 1.1970800000000001
# 1.267668
# 0.7948970000000001
# 0.431182
# 0.056691000000000005
# 1.062233
# 0.555771
# 0.6189629999999999
# 0.507643
# 1.0162660000000001
# 1.209773
# 0.855944
# 0.632003
# 0.6284639999999999
# 1.154851
# 0.763104
# 1.076998
# 0.772712
# 1.232991
# 0.879564
# 1.232617
# 0.582334
# 0.897149
# 0.446851
# 0.7472540000000001
# 0.188441
# 1.440811
# ...
